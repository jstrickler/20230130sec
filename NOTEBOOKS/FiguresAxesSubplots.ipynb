# %%
# %load imports.py
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn
seaborn.set()

# %%
x_data = [abs(x) for x in np.random.randn(30)]
x_data
# Out:
# [1.1311576117459559,
#  1.4105002426570044,
#  0.2540407572977682,
#  1.1873972380408075,
#  0.7361399235006538,
#  0.10507732808992654,
#  0.24320813194462543,
#  0.5447980621682235,
#  0.0284606937815894,
#  0.8979852788382984,
#  0.22137351716270107,
#  1.884806478615462,
#  0.2433476338629585,
#  0.5684350686966491,
#  0.1896645384087134,
#  1.1290676049032304,
#  1.1820468781244484,
#  0.5490413260644507,
#  0.08018573280181449,
#  0.10001688964219617,
#  1.6631840282895165,
#  0.21853637593572905,
#  1.622077141661142,
#  2.093073169470224,
#  0.5939748969290205,
#  1.5168190169291287,
#  0.5656381541504676,
#  1.5392119042191048,
#  0.6958387169449552,
#  0.30196075810169676]

# %%
plt.plot(x_data)
