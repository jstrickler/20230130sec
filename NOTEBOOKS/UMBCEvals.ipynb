# %%
import pandas as pd

# %%
df = pd.read_excel("../UMBC/Advanced Python export.xlsx")

# %%
df.head()
# Out:
#        Date Submitted                   CourseName  StartDate    EndDate  \
# 0 2018-11-02 12:02:01  Advanced Python Programming 2018-10-29 2018-11-02
# 1 2018-11-02 09:10:47  Advanced Python Programming 2018-10-29 2018-11-02
# 2 2018-11-02 09:11:04  Advanced Python Programming 2018-10-29 2018-11-02
# 3 2018-11-02 09:10:51  Advanced Python Programming 2018-10-29 2018-11-02
# 4 2018-11-02 15:27:20  Advanced Python Programming 2018-10-29 2018-11-02
#
#   Instructor Name  \
# 0       Lou Marco
# 1       Lou Marco
# 2       Lou Marco
# 3       Lou Marco
# 4       Lou Marco
#
#    How would you rate your knowledge, skills, and abilities in the course content before taking this course?:Please rate the following aspects of the course content.  \
# 0                                                  5
# 1                                                  4
# 2                                                  3
# 3                                                  5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 35 columns):
# Date Submitted                                                                                                                                                                                       17 non-null datetime64[ns]
# CourseName                                                                                                                                                                                           17 non-null object
# StartDate                                                                                                                                                                                            17 non-null datetime64[ns]
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.columns
# Out:
# Index(['Date Submitted', 'CourseName', 'StartDate', 'EndDate',
#        'Instructor Name',
#        'How would you rate your knowledge, skills, and abilities in the course content before taking this course?:Please rate the following aspects of the course content.',
#        'How would you rate your knowledge, skills, and abilities in the course content after taking this course?:Please rate the following aspects of the course content.',
#        'How well did this course meet your objectives based on the course description?:Please rate the following aspects of the course content.',
#        'How would you rate the course materials?:Please rate the following aspects of the course content.',
#        'How would you rate the course content overall?',
#        'We see that you have rated the overall course content as "Poor". Would you take a moment to tell us how we could do better in this area?',
# ...

# %%
print(df['We see that you have rated the overall course content as "Below Average". Would you take a moment to tell us how we could do better in this area?'
][[11]])
# Out:
# 11    This was billed as an "Advanced Python" course...
# Name: We see that you have rated the overall course content as "Below Average". Would you take a moment to tell us how we could do better in this area?, dtype: object
